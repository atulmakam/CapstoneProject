# %%
#Author: Atul Makam
import numpy as np
import pandas as pd
import re

# %%
#Author: Atul Makam
#Reading district 1 csv file
df1 = pd.read_csv('district1.csv')
# Out:
# /Users/atulmakam/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (2,4,6,525,526,527,528,529,530,531,532,533,534,535,536,537,538,539,540,541,542,543,544,545,546,547,548,549,550,551,552,553,554,573,574,575,576,577,578,579,580,581,582,583,584,585,586,587,588,589,590,591,592,593,594,595,596,597,598,599,600,601,602,603,604,605,606,607,608,609,610,611,613,614,633,634,635,636,637,638,639,640,641,642,643,644,645,646,647,648,649,650,651,652,653,654,655,656,657,658,659,660,661,662,663,664,665,666,667,668,669,670,671,672,673,674,693,694,695,696,697,698,699,700,701,702,703,704,705,706,707,708,709,710,711,712,713,714,715,716,717,718,719,720,721,722,729,730,731,732,733,734,735,736,737,738,739,740,741,742,743,744,745,746,747,748,749,750,751,752,753,754,755,756,757,758,759,760,761,762,763,764,765,766,767,768,769,770) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
#Author: Atul Makam
df1.head()
# Out:
#    study_id  duplicate  birth_date  district gender  hispanic_indicator  \
# 0  111152.0        NaN  10/25/2002         1      F                   1
# 1  111154.0        NaN   3/20/2001         1      F                   1
# 2  111158.0        NaN   3/27/2003         1      F                   0
# 3  111172.0        NaN  12/11/2001         1      F                   1
# 4  111178.0        NaN   5/12/2004         1      F                   1
#
#                 ethnicity  sped_indicator  ell_indicator  \
# 0                   White               0              0
# 1                   White               0              0
# 2  Black/African American               0              0
# 3                   White               1              0
# 4                   White               0              1
#
#    free_reduced_lunch_indicator  ...  FY2019college3_name  \
# 0                             1  ...                  NaN
# 1                             0  ...                  NaN
# ...

# %%
#Author: Atul Makam
#Reading district 2 csv file
df2 = pd.read_csv('district2.csv')
# Out:
# /Users/atulmakam/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (64,67,70,73,76,79,82,85,88,91,94,97,100,103,106,109,112,115,118,121,124,127,130,133,136,139,145,148,151,154,157,163,166,172,175,178,181,184,187,190,193,196,202,205,208,211,214,217,220,223,235,238,241,244,247,250,253,256,259,262,265,268,271,274,277,280,283,286,289,292,295,298,301,304,307,310,313,316,319,322,328,331,334,337,340,343,346,349,352,355,358,361,364,367,370,373,376,379,382,385,388,391,394,397,400,403,406,412,415,418,421,424,427,430,433,436,439,442,445,448,451,454,457,466,467,468,469,470,471,472,473,474,475,476,477,478,479,480,481,482,483,484,485,486,487,488,489,490,491,492,493,494,495,496,497,498,499,500,501,520,521,522,523,524,525,526,527,528,529,530,531,532,533,534,535,536,537,538,539,540,542,543,562,563,564,565,566,567,568,569,570,571,572,573,574,575,576,577,578,579,580,581,582,583,584,585,586,587,588,589,590,591,592,593,594,595,596,597,598,599,600,601,6
# ...

# %%
df2.head()
# Out:
#     study_id  duplicate  birth_date  district gender        ethnicity  \
# 0  1113631.0        NaN   1/23/1996         2      F  Hispanic/Latino
# 1  1119371.0        NaN   3/29/1996         2      F            White
# 2  1119961.0        NaN   4/21/1996         2      M  Hispanic/Latino
# 3  1161336.0        NaN  11/30/1996         2      M  Hispanic/Latino
# 4  1161776.0        NaN  12/24/1995         2      F  Hispanic/Latino
#
#    ell_indicator  sped_indicator  free_reduced_lunch_indicator  \
# 0              0               0                             0
# 1              0               0                             1
# 2              0               0                             0
# 3              0               0                             0
# 4              0               0                             0
#
#    FY2014grade_level  ...  FY2018college2_public_private  \
# 0               12.0  ...                            NaN
# ...

# %%
#Author: Atul Makam
#Reading district 3 csv file
df3 = pd.read_csv('district3.csv')
# Out:
# /Users/atulmakam/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (2,4,5,295,296,297,298,299,300,301,302,303,304,305,306,307,308,309,310,311,312,313,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,338,339,340,341,342,343,344,345,346,347,348,349,350,351,352,353,354,355,356,357,358,359,360,361,362,363,364,365,366,367,368,369,370,371,372,373,374,375,376,377,378,379,380,381,382,383,384,385,386,387,388,389,390,391,392,393,394,395,396,397,398,399,400,401,402,403,404,405,406,407,408,409,410,411,412,413,414,415,416,417,418,419,420,421,422,423,424,425,426,427,428,429,430,431,432,433,434,435,436,437,438,439,440,441,442,443,444,445,446,447,448,449,450,451,452,453,454,455,456,457,458,459,460,461,462,463,464,465,466,467,468,469,470,471,472,473,474,475,476,477,478,479,480,481,482,483,484,485,486,487,488,489,490,491,492,493,494,495,496,497,498,499,500,501,502,503,504,505,506,507,508,509,510,511,512
# ...

# %%
df3.head()
# Out:
#       study_id  duplicate  birth_date  district gender  \
# 0  102966224.0        NaN   3/23/2001         3      F
# 1  102966226.0        NaN    2/2/2001         3      M
# 2  102966229.0        NaN    4/2/2001         3      M
# 3  102966242.0        NaN  10/30/2001         3      M
# 4  102966244.0        NaN    4/4/2001         3      F
#
#                 ethnicity  ell_indicator  sped_indicator  \
# 0             Two or More              0               0
# 1         Hispanic/Latino              0               0
# 2                   White              0               0
# 3  Black/African American              0               0
# 4                   White              0               0
#
#    FY2014high_school_code  FY2014high_school_code_school2  ...  \
# 0                     NaN                             NaN  ...
# 1                     NaN                             NaN  ...
# 2                     NaN                             NaN  ...
# ...

# %%
#Author: Atul Makam
#Reading district 4 csv file
df4 = pd.read_csv('district4.csv')
# Out:
# /Users/atulmakam/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (1,3,4,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128,129,130,131,132,133,134,135,136,137,138,139,140,141,142,143,144,145,146,147,148,149,150,151,152,153,154,155,156,157,158,159,160,161,162,163,164,165,166,167,168,169,170,171,172,173,174,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189,190,191,192,193,194,195,196,197,198,199,200,201,202,203,204,205,206,207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,253,254,255,256,257,258,259,260,261,262,263,264,265,266,267,268,269,270,271,272,273,274,275,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,291,292,293,294,295,296,297,298,299,300,301,302,303,304,305,306,307,308,309,310,311,312,313,314,315,316,317,318,319,320,321,322,323
# ...

# %%
df4.head()
# Out:
#      study_id birth_date  district gender               ethnicity  \
# 0  2222173433        NaN         4      M         Hispanic/Latino
# 1  2222173434        NaN         4      F         Hispanic/Latino
# 2  2222173435        NaN         4      F         Hispanic/Latino
# 3  2222173445        NaN         4      F         Hispanic/Latino
# 4  2222173449        NaN         4      M  Black/African American
#
#    ell_indicator  sped_indicator  FY2014high_school_code  \
# 0              0               0                     NaN
# 1              0               0                     NaN
# 2              0               0                     NaN
# 3              0               0                     NaN
# 4              0               0                     NaN
#
#    FY2014high_school_code_school2  FY2014high_school_code_school3  ...  \
# 0                             NaN                             NaN  ...
# 1                             NaN                             NaN  ...
# ...

# %%
#Author: Atul Makam
#Reading district 5 csv file
df5 = pd.read_csv('district5.csv')
# Out:
# /Users/atulmakam/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (3,4,5,14,15,16,17,18,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128,129,130,131,132,134,135,136,137,138,140,141,142,143,144,145,146,147,148,149,150,151,152,153,154,155,156,157,158,159,160,161,162,163,164,165,166,167,168,169,170,171,172,173,174,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189,190,191,192,193,194,195,196,197,198,200,201,202,203,204,206,207,208,209,210,212,213,214,215,216,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,253,254,255,256,257,258,259,260,261,262,263,264,265,266,267,268,269,270,271,272,273,274,275,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,291,292,293,294,295,296,297,298,299,300,301,302,303,304,305,306,307,308,309,310,311,312,313,314
# ...

# %%
df5.head()
# Out:
#       study_id  duplicate  district birth_date gender        ethnicity  \
# 0   44131344.0        NaN         5        NaN      F  Hispanic/Latino
# 1  152644444.0        NaN         5  6/12/1997    NaN              NaN
# 2  181344422.0        NaN         5        NaN      F  Hispanic/Latino
# 3  182244426.0        NaN         5        NaN      M            White
# 4  441825204.0        NaN         5        NaN      M  Hispanic/Latino
#
#    ell_indicator  sped_indicator  free_reduced_lunch_indicator  \
# 0              0               0                             1
# 1              0               0                             0
# 2              0               0                             0
# 3              0               0                             1
# 4              0               0                             1
#
#    FY2013grade_level  ...  FY2018college13_public_private  college_grad_date1  \
# ...

# %%
#Author: Atul Makam
#Concatenation of the files
dfm = pd.concat([df1, df2, df3, df4, df5], axis = 0, sort = True)

# %%
dfm.head()
# Out:
#    FY2008AIMS_math_perf_level  FY2008AIMS_math_score  \
# 0                         NaN                    NaN
# 1                         NaN                    NaN
# 2                         NaN                    NaN
# 3                         NaN                    NaN
# 4                         NaN                    NaN
#
#    FY2008AIMS_reading_perf_level  FY2008AIMS_reading_score  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       NaN
# 3                            NaN                       NaN
# 4                            NaN                       NaN
#
#    FY2008AIMS_science_perf_level  FY2008AIMS_science_score  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       NaN
# ...

# %%
dfm.describe()
# Out:
#        FY2008AIMS_math_perf_level  FY2008AIMS_math_score  \
# count                12986.000000           12986.000000
# mean                     3.055059             508.821808
# std                      0.838321              64.493546
# min                      1.000000             328.000000
# 25%                      3.000000             464.000000
# 50%                      3.000000             509.000000
# 75%                      4.000000             549.000000
# max                      4.000000             740.000000
#
#        FY2008AIMS_reading_perf_level  FY2008AIMS_reading_score  \
# count                   12987.000000              12987.000000
# mean                        2.842304                491.137214
# std                         0.708306                 52.424475
# min                         1.000000                313.000000
# 25%                         3.000000                455.500000
# 50%                         3.000000                493.000000
# ...

# %%
df_cols = [dfm.columns]

# %%
#Author: Atul Makam
#Searching for duplicate columns 
def Repeat(x): 
    _size = len(x) 
    repeated = [] 
    for i in range(_size): 
        k = i + 1
        for j in range(k, _size): 
            if x[i] == x[j] and x[i] not in repeated: 
                repeated.append(x[i]) 
    return repeated

# %%
print(Repeat(df_cols))
# Out:
# []

# %%
#Author: Atul Makam
#Extracting the column names
df_cols_districts = pd.DataFrame(df_cols)

# %%
df_cols_districts
# Out:
#                          0                      1     \
# 0  FY2008AIMS_math_perf_level  FY2008AIMS_math_score
#
#                             2                         3     \
# 0  FY2008AIMS_reading_perf_level  FY2008AIMS_reading_score
#
#                             4                         5     \
# 0  FY2008AIMS_science_perf_level  FY2008AIMS_science_score
#
#                             6                         7     \
# 0  FY2008AIMS_writing_perf_level  FY2008AIMS_writing_score
#
#                          8                      9     ...      1651  \
# 0  FY2009AIMS_math_perf_level  FY2009AIMS_math_score  ...  district
#
#         1652           1653       1654                          1655    1656  \
# 0  duplicate  ell_indicator  ethnicity  free_reduced_lunch_indicator  gender
#
#                     1657                1658            1659      1660
# 0  high_school_grad_date  hispanic_indicator  sped_indicator  study_id
#
# [1 rows x 1661 columns]

# %%
df_cols_districts.to_csv('columns2.csv')

# %%
dfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 255004 entries, 0 to 77031
# Columns: 1661 entries, FY2008AIMS_math_perf_level to study_id
# dtypes: float64(789), int64(3), object(869)
# memory usage: 3.2+ GB

# %%
#Author: Atul Makam
#Checking the data types of the columns 
dfm.dtypes
# Out:
# FY2008AIMS_math_perf_level       float64
# FY2008AIMS_math_score            float64
# FY2008AIMS_reading_perf_level    float64
# FY2008AIMS_reading_score         float64
# FY2008AIMS_science_perf_level    float64
#                                   ...
# gender                            object
# high_school_grad_date             object
# hispanic_indicator               float64
# sped_indicator                     int64
# study_id                         float64
# Length: 1661, dtype: object

# %%
#Author: Atul Makam
# Checking the number of missing values
dfm.isna().sum()
# Out:
# FY2008AIMS_math_perf_level       242018
# FY2008AIMS_math_score            242018
# FY2008AIMS_reading_perf_level    242017
# FY2008AIMS_reading_score         242017
# FY2008AIMS_science_perf_level    251810
#                                   ...
# gender                            35868
# high_school_grad_date            183842
# hispanic_indicator               183529
# sped_indicator                        0
# study_id                              0
# Length: 1661, dtype: int64

# %%
dfm.isnull().sum()
# Out:
# FY2008AIMS_math_perf_level       242018
# FY2008AIMS_math_score            242018
# FY2008AIMS_reading_perf_level    242017
# FY2008AIMS_reading_score         242017
# FY2008AIMS_science_perf_level    251810
#                                   ...
# gender                            35868
# high_school_grad_date            183842
# hispanic_indicator               183529
# sped_indicator                        0
# study_id                              0
# Length: 1661, dtype: int64

# %%
dfm.shape
# Out:
# (255004, 1661)

# %%
df_cols_merged1 = [dfm.columns]
df_cols_districts_merged1 = pd.DataFrame(df_cols)
df_cols_districts_merged1.to_csv('columns_merged1.csv')

# %%
dfm
# Out:
#        FY2008AIMS_math_perf_level  FY2008AIMS_math_score  \
# 0                             NaN                    NaN
# 1                             NaN                    NaN
# 2                             NaN                    NaN
# 3                             NaN                    NaN
# 4                             NaN                    NaN
# ...                           ...                    ...
# 77027                         NaN                    NaN
# 77028                         NaN                    NaN
# 77029                         NaN                    NaN
# 77030                         NaN                    NaN
# 77031                         NaN                    NaN
#
#        FY2008AIMS_reading_perf_level  FY2008AIMS_reading_score  \
# 0                                NaN                       NaN
# 1                                NaN                       NaN
# 2                                NaN                       NaN
# ...

# %%
#Author: Atul Makam
#Extracting only specific columns 
cols = [c for c in dfm.columns if c != ('FY2008' and 'FY2009' and 'FY2010' and 'FY2011' and 'FY2012' and 'FY2013' and 'FY2019')]

# %%
dfm=dfm[cols]

# %%
dfm
# Out:
#        FY2008AIMS_math_perf_level  FY2008AIMS_math_score  \
# 0                             NaN                    NaN
# 1                             NaN                    NaN
# 2                             NaN                    NaN
# 3                             NaN                    NaN
# 4                             NaN                    NaN
# ...                           ...                    ...
# 77027                         NaN                    NaN
# 77028                         NaN                    NaN
# 77029                         NaN                    NaN
# 77030                         NaN                    NaN
# 77031                         NaN                    NaN
#
#        FY2008AIMS_reading_perf_level  FY2008AIMS_reading_score  \
# 0                                NaN                       NaN
# 1                                NaN                       NaN
# 2                                NaN                       NaN
# ...

# %%
df_cols_merged1 = [dfm.columns]
df_cols_districts_merged1 = pd.DataFrame(df_cols)
df_cols_districts_merged1.to_csv('columns_merged2.csv')

# %%
dfm1 = dfm.copy()

# %%
dfm1
# Out:
#        FY2008AIMS_math_perf_level  FY2008AIMS_math_score  \
# 0                             NaN                    NaN
# 1                             NaN                    NaN
# 2                             NaN                    NaN
# 3                             NaN                    NaN
# 4                             NaN                    NaN
# ...                           ...                    ...
# 77027                         NaN                    NaN
# 77028                         NaN                    NaN
# 77029                         NaN                    NaN
# 77030                         NaN                    NaN
# 77031                         NaN                    NaN
#
#        FY2008AIMS_reading_perf_level  FY2008AIMS_reading_score  \
# 0                                NaN                       NaN
# 1                                NaN                       NaN
# 2                                NaN                       NaN
# ...

# %%
dfm1.columns
# Out:
# Index(['FY2008AIMS_math_perf_level', 'FY2008AIMS_math_score',
#        'FY2008AIMS_reading_perf_level', 'FY2008AIMS_reading_score',
#        'FY2008AIMS_science_perf_level', 'FY2008AIMS_science_score',
#        'FY2008AIMS_writing_perf_level', 'FY2008AIMS_writing_score',
#        'FY2009AIMS_math_perf_level', 'FY2009AIMS_math_score',
#        ...
#        'district', 'duplicate', 'ell_indicator', 'ethnicity',
#        'free_reduced_lunch_indicator', 'gender', 'high_school_grad_date',
#        'hispanic_indicator', 'sped_indicator', 'study_id'],
#       dtype='object', length=1661)

# %%
dfm1
# Out:
#        FY2008AIMS_math_perf_level  FY2008AIMS_math_score  \
# 0                             NaN                    NaN
# 1                             NaN                    NaN
# 2                             NaN                    NaN
# 3                             NaN                    NaN
# 4                             NaN                    NaN
# ...                           ...                    ...
# 77027                         NaN                    NaN
# 77028                         NaN                    NaN
# 77029                         NaN                    NaN
# 77030                         NaN                    NaN
# 77031                         NaN                    NaN
#
#        FY2008AIMS_reading_perf_level  FY2008AIMS_reading_score  \
# 0                                NaN                       NaN
# 1                                NaN                       NaN
# 2                                NaN                       NaN
# ...

# %%
d = dfm1.columns

# %%
d
# Out:
# Index(['FY2008AIMS_math_perf_level', 'FY2008AIMS_math_score',
#        'FY2008AIMS_reading_perf_level', 'FY2008AIMS_reading_score',
#        'FY2008AIMS_science_perf_level', 'FY2008AIMS_science_score',
#        'FY2008AIMS_writing_perf_level', 'FY2008AIMS_writing_score',
#        'FY2009AIMS_math_perf_level', 'FY2009AIMS_math_score',
#        ...
#        'district', 'duplicate', 'ell_indicator', 'ethnicity',
#        'free_reduced_lunch_indicator', 'gender', 'high_school_grad_date',
#        'hispanic_indicator', 'sped_indicator', 'study_id'],
#       dtype='object', length=1661)

# %%
#Author: Atul Makam
#Dropping columns where year is 2008
regex=re.compile(r'FY2008.*')
d=list(filter(lambda x: True if regex.search(x)==None else False, d))

# %%
d
# Out:
# ['FY2009AIMS_math_perf_level',
#  'FY2009AIMS_math_score',
#  'FY2009AIMS_reading_perf_level',
#  'FY2009AIMS_reading_score',
#  'FY2009AIMS_science_perf_level',
#  'FY2009AIMS_science_score',
#  'FY2009AIMS_writing_perf_level',
#  'FY2009AIMS_writing_score',
#  'FY2009college1_begin_date',
#  'FY2009college1_end_date',
#  'FY2009college1_enrollment_status',
#  'FY2009college1_name',
#  'FY2009college1_public_private',
#  'FY2009college1_type2or4year',
#  'FY2009college2_begin_date',
#  'FY2009college2_end_date',
#  'FY2009college2_enrollment_status',
#  'FY2009college2_name',
#  'FY2009college2_public_private',
#  'FY2009college2_type2or4year',
#  'FY2010ACT_composite_perf_level',
#  'FY2010ACT_composite_score',
#  'FY2010AIMS_math_perf_level',
#  'FY2010AIMS_math_score',
#  'FY2010AIMS_reading_perf_level',
#  'FY2010AIMS_reading_score',
#  'FY2010AIMS_science_perf_level',
#  'FY2010AIMS_science_score',
#  'FY2010AIMS_writing_perf_level',
#  'FY2010AIMS_writing_score',
# ...

# %%
#Author: Atul Makam
#Dropping columns where year is 2009
regex=re.compile(r'FY2009.*')
d=list(filter(lambda x: True if regex.search(x)==None else False, d))
d
# Out:
# ['FY2010ACT_composite_perf_level',
#  'FY2010ACT_composite_score',
#  'FY2010AIMS_math_perf_level',
#  'FY2010AIMS_math_score',
#  'FY2010AIMS_reading_perf_level',
#  'FY2010AIMS_reading_score',
#  'FY2010AIMS_science_perf_level',
#  'FY2010AIMS_science_score',
#  'FY2010AIMS_writing_perf_level',
#  'FY2010AIMS_writing_score',
#  'FY2010college1_begin_date',
#  'FY2010college1_end_date',
#  'FY2010college1_enrollment_status',
#  'FY2010college1_name',
#  'FY2010college1_public_private',
#  'FY2010college1_type2or4year',
#  'FY2010college2_begin_date',
#  'FY2010college2_end_date',
#  'FY2010college2_enrollment_status',
#  'FY2010college2_name',
#  'FY2010college2_public_private',
#  'FY2010college2_type2or4year',
#  'FY2010college3_begin_date',
#  'FY2010college3_end_date',
#  'FY2010college3_enrollment_status',
#  'FY2010college3_name',
#  'FY2010college3_public_private',
#  'FY2010college3_type2or4year',
#  'FY2010college4_begin_date',
#  'FY2010college4_end_date',
# ...

# %%
#Author: Atul Makam
#Dropping columns where year is 2010
regex=re.compile(r'FY2010.*')
d=list(filter(lambda x: True if regex.search(x)==None else False, d))
d
# Out:
# ['FY2011AIMS_math_perf_level',
#  'FY2011AIMS_math_score',
#  'FY2011AIMS_reading_perf_level',
#  'FY2011AIMS_reading_score',
#  'FY2011AIMS_science_perf_level',
#  'FY2011AIMS_science_score',
#  'FY2011AIMS_writing_perf_level',
#  'FY2011AIMS_writing_score',
#  'FY2011college10_begin_date',
#  'FY2011college10_end_date',
#  'FY2011college10_enrollment_status',
#  'FY2011college10_name',
#  'FY2011college10_public_private',
#  'FY2011college10_type2or4year',
#  'FY2011college1_begin_date',
#  'FY2011college1_end_date',
#  'FY2011college1_enrollment_status',
#  'FY2011college1_name',
#  'FY2011college1_public_private',
#  'FY2011college1_type2or4year',
#  'FY2011college2_begin_date',
#  'FY2011college2_end_date',
#  'FY2011college2_enrollment_status',
#  'FY2011college2_name',
#  'FY2011college2_public_private',
#  'FY2011college2_type2or4year',
#  'FY2011college3_begin_date',
#  'FY2011college3_end_date',
#  'FY2011college3_enrollment_status',
#  'FY2011college3_name',
# ...

# %%
#Author: Atul Makam
#Dropping columns where year is 2011
regex=re.compile(r'FY2011.*')
d=list(filter(lambda x: True if regex.search(x)==None else False, d))
d
# Out:
# ['FY2012ACT_composite_perf_level',
#  'FY2012ACT_composite_score',
#  'FY2012AIMS_math_perf_level',
#  'FY2012AIMS_math_score',
#  'FY2012AIMS_reading_perf_level',
#  'FY2012AIMS_reading_score',
#  'FY2012AIMS_science_perf_level',
#  'FY2012AIMS_science_score',
#  'FY2012AIMS_writing_perf_level',
#  'FY2012AIMS_writing_score',
#  'FY2012college10_begin_date',
#  'FY2012college10_end_date',
#  'FY2012college10_enrollment_status',
#  'FY2012college10_name',
#  'FY2012college10_public_private',
#  'FY2012college10_type2or4year',
#  'FY2012college11_begin_date',
#  'FY2012college11_end_date',
#  'FY2012college11_enrollment_status',
#  'FY2012college11_name',
#  'FY2012college11_public_private',
#  'FY2012college11_type2or4year',
#  'FY2012college12_begin_date',
#  'FY2012college12_end_date',
#  'FY2012college12_enrollment_status',
#  'FY2012college12_name',
#  'FY2012college12_public_private',
#  'FY2012college12_type2or4year',
#  'FY2012college13_begin_date',
# ...

# %%
#Author: Atul Makam
#Dropping columns where year is 2012
regex=re.compile(r'FY2012.*')
d=list(filter(lambda x: True if regex.search(x)==None else False, d))
d
# Out:
# ['FY2013ACT_composite_perf_level',
#  'FY2013ACT_composite_score',
#  'FY2013ACT_english_perf_level',
#  'FY2013ACT_english_score',
#  'FY2013ACT_math_perf_level',
#  'FY2013ACT_math_score',
#  'FY2013ACT_reading_perf_level',
#  'FY2013ACT_reading_score',
#  'FY2013ACT_science_perf_level',
#  'FY2013ACT_science_score',
#  'FY2013AIMS_math_perf_level',
#  'FY2013AIMS_math_score',
#  'FY2013AIMS_reading_perf_level',
#  'FY2013AIMS_reading_score',
#  'FY2013AIMS_science_perf_level',
#  'FY2013AIMS_science_score',
#  'FY2013AIMS_writing_perf_level',
#  'FY2013AIMS_writing_score',
#  'FY2013SAT_Math_perf_level',
#  'FY2013SAT_Math_score',
#  'FY2013SAT_Reading_perf_level',
#  'FY2013SAT_Reading_score',
#  'FY2013SAT_Total_perf_level',
#  'FY2013SAT_Total_score',
#  'FY2013SAT_Writing_perf_level',
#  'FY2013SAT_Writing_score',
#  'FY2013college10_begin_date',
#  'FY2013college10_end_date',
#  'FY2013college10_enrollment_status',
#  'FY2013college10_name',
# ...

# %%
#Author: Atul Makam
#Dropping columns where year is 2013
regex=re.compile(r'FY2013.*')
d=list(filter(lambda x: True if regex.search(x)==None else False, d))
d
# Out:
# ['FY2014ACT_composite_perf_level',
#  'FY2014ACT_composite_score',
#  'FY2014ACT_english_perf_level',
#  'FY2014ACT_english_score',
#  'FY2014ACT_math_perf_level',
#  'FY2014ACT_math_score',
#  'FY2014ACT_reading_perf_level',
#  'FY2014ACT_reading_score',
#  'FY2014ACT_science_perf_level',
#  'FY2014ACT_science_score',
#  'FY2014AIMS_math_perf_level',
#  'FY2014AIMS_math_score',
#  'FY2014AIMS_reading_perf_level',
#  'FY2014AIMS_reading_score',
#  'FY2014AIMS_science_perf_level',
#  'FY2014AIMS_science_perf_level.1',
#  'FY2014AIMS_science_score',
#  'FY2014AIMS_writing_perf_level',
#  'FY2014AIMS_writing_score',
#  'FY2014AP_artHistory_course_letter_grade',
#  'FY2014AP_artHistory_course_number_grade',
#  'FY2014AP_artHistory_score',
#  'FY2014AP_biology_course_letter_grade',
#  'FY2014AP_biology_course_number_grade',
#  'FY2014AP_biology_score',
#  'FY2014AP_calcBC_score',
#  'FY2014AP_calculusAB_course_letter_grade',
#  'FY2014AP_calculusAB_course_number_grade',
# ...

# %%
#Author: Atul Makam
#Dropping columns where year is 2019
regex=re.compile(r'FY2019.*')
d=list(filter(lambda x: True if regex.search(x)==None else False, d))
d
# Out:
# ['FY2014ACT_composite_perf_level',
#  'FY2014ACT_composite_score',
#  'FY2014ACT_english_perf_level',
#  'FY2014ACT_english_score',
#  'FY2014ACT_math_perf_level',
#  'FY2014ACT_math_score',
#  'FY2014ACT_reading_perf_level',
#  'FY2014ACT_reading_score',
#  'FY2014ACT_science_perf_level',
#  'FY2014ACT_science_score',
#  'FY2014AIMS_math_perf_level',
#  'FY2014AIMS_math_score',
#  'FY2014AIMS_reading_perf_level',
#  'FY2014AIMS_reading_score',
#  'FY2014AIMS_science_perf_level',
#  'FY2014AIMS_science_perf_level.1',
#  'FY2014AIMS_science_score',
#  'FY2014AIMS_writing_perf_level',
#  'FY2014AIMS_writing_score',
#  'FY2014AP_artHistory_course_letter_grade',
#  'FY2014AP_artHistory_course_number_grade',
#  'FY2014AP_artHistory_score',
#  'FY2014AP_biology_course_letter_grade',
#  'FY2014AP_biology_course_number_grade',
#  'FY2014AP_biology_score',
#  'FY2014AP_calcBC_score',
#  'FY2014AP_calculusAB_course_letter_grade',
#  'FY2014AP_calculusAB_course_number_grade',
# ...

# %%
#Author: Atul Makam
#Removing the set of columns 
lst = list(set(dfm1.columns) - set(d))
lst
# Out:
# ['FY2010college5_begin_date',
#  'FY2009AIMS_math_perf_level',
#  'FY2010college9_type2or4year',
#  'FY2010college5_type2or4year',
#  'FY2013college13_enrollment_status',
#  'FY2013college2_name',
#  'FY2010AIMS_reading_perf_level',
#  'FY2012AIMS_writing_score',
#  'FY2013college4_enrollment_status',
#  'FY2011college2_type2or4year',
#  'FY2012college10_public_private',
#  'FY2010college7_name',
#  'FY2019ACT_science_score',
#  'FY2010college4_enrollment_status',
#  'FY2019AzMerit_ELA9_perf_level',
#  'FY2012college9_type2or4year',
#  'FY2010AIMS_writing_perf_level',
#  'FY2011college1_enrollment_status',
#  'FY2011college5_enrollment_status',
#  'FY2019college9_name',
#  'FY2013college11_name',
#  'FY2019AP_germanLang_score',
#  'FY2013high_school_code3',
#  'FY2013ACT_english_perf_level',
#  'FY2012college13_type2or4year',
#  'FY2013ACT_science_perf_level',
#  'FY2019AzMerit_Math8_score',
#  'FY2019AP_compSciPrincip_score',
#  'FY2010ACT_composite_perf_level',
# ...

# %%
#Author: Atul Makam
#Dropping the list of columns
dfm1.drop(columns= lst, inplace=True)

# %%
dfm1
# Out:
#        FY2014ACT_composite_perf_level  FY2014ACT_composite_score  \
# 0                                 NaN                        NaN
# 1                                 NaN                        NaN
# 2                                 NaN                        NaN
# 3                                 NaN                        NaN
# 4                                 NaN                        NaN
# ...                               ...                        ...
# 77027                             NaN                        NaN
# 77028                             NaN                        NaN
# 77029                             NaN                        NaN
# 77030                             NaN                        NaN
# 77031                             NaN                        NaN
#
#        FY2014ACT_english_perf_level  FY2014ACT_english_score  \
# 0                               NaN                      NaN
# ...

# %%
d = dfm1.columns

# %%
#Author: Atul Makam
#Counting number of values for performance level
dfm1['FY2014ACT_math_perf_level'].value_counts()
# Out:
# 3.0    488
# 2.0    289
# Name: FY2014ACT_math_perf_level, dtype: int64

# %%
#Author: Atul Makam
#Counting number of values for scores
dfm1['FY2014ACT_math_score'].value_counts()
# Out:
# 26.0    79
# 16.0    68
# 25.0    66
# 17.0    64
# 23.0    60
# 27.0    55
# 24.0    53
# 28.0    40
# 21.0    35
# 29.0    33
# 19.0    32
# 15.0    30
# 18.0    29
# 20.0    24
# 22.0    23
# 30.0    20
# 32.0    17
# 33.0    16
# 31.0    11
# 34.0     9
# 14.0     4
# 36.0     3
# 35.0     3
# 12.0     2
# 13.0     1
# Name: FY2014ACT_math_score, dtype: int64

# %%
#Author: Atul Makam
#Extracting list of columns with _score
regex=re.compile(r'.*_score')
d=list(filter(lambda x: True if regex.search(x)==None else False, d))
d
# Out:
# ['FY2014ACT_composite_perf_level',
#  'FY2014ACT_english_perf_level',
#  'FY2014ACT_math_perf_level',
#  'FY2014ACT_reading_perf_level',
#  'FY2014ACT_science_perf_level',
#  'FY2014AIMS_math_perf_level',
#  'FY2014AIMS_reading_perf_level',
#  'FY2014AIMS_science_perf_level',
#  'FY2014AIMS_science_perf_level.1',
#  'FY2014AIMS_writing_perf_level',
#  'FY2014AP_artHistory_course_letter_grade',
#  'FY2014AP_artHistory_course_number_grade',
#  'FY2014AP_biology_course_letter_grade',
#  'FY2014AP_biology_course_number_grade',
#  'FY2014AP_calculusAB_course_letter_grade',
#  'FY2014AP_calculusAB_course_number_grade',
#  'FY2014AP_calculusBCABsubscore_course_letter_grade',
#  'FY2014AP_calculusBCABsubscore_course_number_grade',
#  'FY2014AP_calculusBC_course_letter_grade',
#  'FY2014AP_calculusBC_course_number_grade',
#  'FY2014AP_chemistry_course_letter_grade',
#  'FY2014AP_chemistry_course_number_grade',
#  'FY2014AP_econMacro_course_letter_grade',
# ...

# %%
#Author: Atul Makam
#Removing the list of _score columns
lst = list(set(dfm1.columns) - set(d))
lst
# Out:
# ['FY2016AP_worldhist_score',
#  'FY2014ACT_composite_score',
#  'FY2014AP_studioArtDraw_score',
#  'FY2016AP_psychology_score',
#  'FY2015AP_physicsCEM_score',
#  'FY2015AP_engLang_score',
#  'FY2017AP_worldHistory_score',
#  'FY2015AP_musicAural_score',
#  'FY2016AP_studioArtDraw_score',
#  'FY2016AP_germanLang_score',
#  'FY2018AP_econMicro_score',
#  'FY2015AP_musicNonaural_score',
#  'FY2016ACT_composite_score',
#  'FY2020ACT_english_score',
#  'FY2015AzMerit_unspecified_math_score',
#  'FY2018AP_spanish_score',
#  'FY2014AP_psychology_score',
#  'FY2017AP_studioArt2D_score',
#  'FY2018AP_ushist_score',
#  'FY2016PSAT_English_score',
#  'FY2017AP_engLit_score',
#  'FY2015AP_govtComparative_score',
#  'FY2018AP_europHistory_score',
#  'FY2018AP_biology_score',
#  'FY2016AP_studioArt3D_score',
#  'FY2017AP_physics2_score',
#  'FY2014AP_chineseLang_score',
#  'FY2017PSAT_English_score',
#  'FY2017AP_worldhist_score',
#  'FY2014AP_computerSciA_score',
# ...

# %%
#Author: Atul Makam
#Dropping the list of columns
dfm1.drop(columns= lst, inplace=True)

# %%
dfm1
# Out:
#        FY2014ACT_composite_perf_level  FY2014ACT_english_perf_level  \
# 0                                 NaN                           NaN
# 1                                 NaN                           NaN
# 2                                 NaN                           NaN
# 3                                 NaN                           NaN
# 4                                 NaN                           NaN
# ...                               ...                           ...
# 77027                             NaN                           NaN
# 77028                             NaN                           NaN
# 77029                             NaN                           NaN
# 77030                             NaN                           NaN
# 77031                             NaN                           NaN
#
#        FY2014ACT_math_perf_level  FY2014ACT_reading_perf_level  \
# 0                            NaN                           NaN
# ...

# %%
#Author: Atul Makam
#Replacing the values in the ethnicity column by the first letter
dfm1.replace({'ethnicity' : { 'Hispanic/Latino' : 'H', 'White' : 'W', 'Black/African American' : 'B', 'American Indian/Alaskan Native': 'AI', 'Asian': 'A', 'Two or More': 'T', 'Native Hawaiian/Pacific Islander': 'NH' }}, inplace = True)

# %%
dfm1
# Out:
#        FY2014ACT_composite_perf_level  FY2014ACT_english_perf_level  \
# 0                                 NaN                           NaN
# 1                                 NaN                           NaN
# 2                                 NaN                           NaN
# 3                                 NaN                           NaN
# 4                                 NaN                           NaN
# ...                               ...                           ...
# 77027                             NaN                           NaN
# 77028                             NaN                           NaN
# 77029                             NaN                           NaN
# 77030                             NaN                           NaN
# 77031                             NaN                           NaN
#
#        FY2014ACT_math_perf_level  FY2014ACT_reading_perf_level  \
# 0                            NaN                           NaN
# ...

# %%
dfm1.columns
# Out:
# Index(['FY2014ACT_composite_perf_level', 'FY2014ACT_english_perf_level',
#        'FY2014ACT_math_perf_level', 'FY2014ACT_reading_perf_level',
#        'FY2014ACT_science_perf_level', 'FY2014AIMS_math_perf_level',
#        'FY2014AIMS_reading_perf_level', 'FY2014AIMS_science_perf_level',
#        'FY2014AIMS_science_perf_level.1', 'FY2014AIMS_writing_perf_level',
#        ...
#        'district', 'duplicate', 'ell_indicator', 'ethnicity',
#        'free_reduced_lunch_indicator', 'gender', 'high_school_grad_date',
#        'hispanic_indicator', 'sped_indicator', 'study_id'],
#       dtype='object', length=846)

# %%
dfm1['ethnicity'].value_counts()
# Out:
# H     98947
# W     87175
# B     15438
# AI     7088
# A      5248
# T      3769
# NH      764
# Name: ethnicity, dtype: int64

# %%
dfm1.dtypes
# Out:
# FY2014ACT_composite_perf_level    float64
# FY2014ACT_english_perf_level      float64
# FY2014ACT_math_perf_level         float64
# FY2014ACT_reading_perf_level      float64
# FY2014ACT_science_perf_level      float64
#                                    ...
# gender                             object
# high_school_grad_date              object
# hispanic_indicator                float64
# sped_indicator                      int64
# study_id                          float64
# Length: 846, dtype: object

# %%
dfm1.to_csv('district_merged_dup_check1.csv')

# %%
dfm1.drop_duplicates(subset='study_id', keep="first")
# Out:
#        FY2014ACT_composite_perf_level  FY2014ACT_english_perf_level  \
# 0                                 NaN                           NaN
# 1                                 NaN                           NaN
# 2                                 NaN                           NaN
# 3                                 NaN                           NaN
# 4                                 NaN                           NaN
# ...                               ...                           ...
# 74750                             NaN                           NaN
# 76301                             NaN                           NaN
# 76303                             NaN                           NaN
# 76304                             NaN                           NaN
# 76305                             NaN                           NaN
#
#        FY2014ACT_math_perf_level  FY2014ACT_reading_perf_level  \
# 0                            NaN                           NaN
# ...
